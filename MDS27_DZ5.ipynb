# %% [markdown]
# <a href="https://colab.research.google.com/github/solobala/MDS27/blob/main/MDS27_DZ5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Домашнее задание "Функции нескольких переменных".

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm # цветовые карты
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import sympy as sym
from sympy import *

# %% [markdown]
# ### Уровень 0:
# Задание 1
# Посчитайте частные производные функций:
#
# ![image.png](data:image/png;base64,...)

# %%
x, y = symbols('x y')
init_printing(use_unicode=True)
# Запишем ф-ю в аналитическом виде и превратим ее в объект

str_expression1 = '2 * x**2 * y**3 + 1/x + y**2 * x +7'
expression1 = sym.sympify(str_expression1)
expression1
# Out:
#    2  3      2       1
# 2⋅x ⋅y  + x⋅y  + 7 + ─
#                      x

# %%
# Выражение для 1 производной ф-ии по x в аналитическом виде
drv_x1 = sym.diff(expression1, x)
drv_x1
# Out:
#      3    2   1
# 4⋅x⋅y  + y  - ──
#                2
#               x

# %%
# Выражение для 1 производной ф-ии по y в аналитическом виде
drv_y1 = sym.diff(expression1, y)
drv_y1
# Out:
#    2  2
# 6⋅x ⋅y  + 2⋅x⋅y

# %% [markdown]
# посчитайте частные производные ф-ии:
#
# ![image.png](data:image/png;base64,...)

# %%
str_expression2 = 'x**2 * y -sin(x*y) + cos(x**2) + 6 * y'
expression2 = sym.sympify(str_expression2)
expression2
# Out:
#  2                         ⎛ 2⎞
# x ⋅y + 6⋅y - sin(x⋅y) + cos⎝x ⎠

# %%
# Выражение для 1 производной ф-ии по x в аналитическом виде
drv_x2 = sym.diff(expression2, x)
drv_x2
# Out:
#                ⎛ 2⎞
# 2⋅x⋅y - 2⋅x⋅sin⎝x ⎠ - y⋅cos(x⋅y)

# %%
# Выражение для 1 производной ф-ии по y в аналитическом виде
drv_y2 = sym.diff(expression2, y)
drv_y2
# Out:
#  2
# x  - x⋅cos(x⋅y) + 6

# %% [markdown]
# ### Уровень 1:
# Задание 2
#
# ![image.png](data:image/png;base64,...)

# %%
x, у = symbols('x y')
# Запишем ф-ю в аналитическом виде и превратим ее в объект

str_expression4 = '2 * x**2 * y**3 + 1/x + y**2 * x + 7'
expression4 = sym.sympify(str_expression4)
expression4
# Out:
#    2  3      2       1
# 2⋅x ⋅y  + x⋅y  + 7 + ─
#                      x

# %%
# Выражение для 1 производной ф-ии по x в аналитическом виде
drv_x4 = sym.diff(expression4, x)
drv_x4
# Out:
#      3    2   1
# 4⋅x⋅y  + y  - ──
#                2
#               x

# %%
# Выражение для 1 производной ф-ии по y в аналитическом виде
drv_y4 = sym.diff(expression4, y)
drv_y4
# Out:
#    2  2
# 6⋅x ⋅y  + 2⋅x⋅y

# %%
print(f' Значение 1-й производной ф-ии {expression4} по направлению x в точке (1,2): {drv_x4.evalf(subs={x:1,y:2})}')
# Out:
#  Значение 1-й производной ф-ии 2*x**2*y**3 + x*y**2 + 7 + 1/x по направлению x в точке (1,2): 35.0000000000000

# %%
print(f' Значение 1-й производной ф-ии {expression4} по направлению y в точке (1,2): {drv_y4.evalf(subs={x:1,y:2})}')
# Out:
#  Значение 1-й производной ф-ии 2*x**2*y**3 + x*y**2 + 7 + 1/x по направлению y в точке (1,2): 28.0000000000000

# %%
print(f' Градиент ф-ии {expression4}  в точке (1,2): ({drv_x4.evalf(subs={x:1,y:2})}, {drv_y4.evalf(subs={x:1,y:2})})')
# Out:
#  Градиент ф-ии 2*x**2*y**3 + x*y**2 + 7 + 1/x  в точке (1,2): (35.0000000000000, 28.0000000000000)

# %% [markdown]
# ### Задание 3
# Постройте трехмерный график функции
# ![image.png](data:image/png;base64,...)

# %%
x1, x2 = symbols('x1 x2')

# Запишем ф-ю в аналитическом виде и превратим ее в объект

str_expression3 = 'x2**2 - x1**2 * x2 + 2 * x1 * x2'
expression3 = sym.sympify(str_expression3)
expression3
# Out:
#     2                  2
# - x₁ ⋅x₂ + 2⋅x₁⋅x₂ + x₂

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# Данные
X = np.arange(-4, 6, 0.25)
Y = np.arange(-4, 6, 0.25)
X, Y = np.meshgrid(X, Y)
Z = Y**2 - X**2 * Y + 2 * X * Y


# График поверхности
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Настройка оси z
ax.set_zlim(-140, 140.0)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Цветовая легенда
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.azim = 15
ax.dist = 10
ax.elev = 30

plt.show()

# %% [markdown]
# # практика: визуализация

# %%
def func02(x,y):
  return x**2 +3*x*y +4*y**2

# %%
func02(1,1)
# Out:
# 8

# %%
delta = 0.02 # это шаг сетки
x = np.arange(-3.0, 3.0, delta) # Кол-во линий и их значени определяются пользователем
y = np.arange(-3.0, 3.0, delta)
X,Y = np.meshgrid(x,y)
Z1 = np.exp(-X**2 -Y**2)
Z2 = np.exp(-(X-1)**2 -(Y-1)**2)
Z = (Z1-Z2)*2

# %%
# Построение графика Линий уровня. 
fig, ax = plt.subplots()
CS = ax.contour(X,Y,Z) # ключевое слово для графика линий уровня
ax.clabel(CS, inline=True, fontsize=3)
ax.set_title("Simplest with labels")
# Out:
# Text(0.5, 1.0, 'Simplest with labels')

# %%
# Построение трехмерного графика - Важно набор команд поместить в 1 ячейку
# Создадим 3-мерную сетку
fig=plt.figure()
ax = fig.gca(projection = '3d')
# Данные
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
# График поверхности
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Настройка оси z
ax.set_zlim(-1, 1.0)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
# Цветовая легенда
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.azim = 15
ax.dist = 10
ax.elev = 30

plt.show()

# %%
# Сложный график с несколькими объектами
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
fig = plt.figure(figsize=(4, 6), dpi=80)
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %%
# Векторные поля - 2D

import matplotlib.gridspec as gridspec

w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

fig = plt.figure(figsize=(15, 18))
gs = gridspec.GridSpec(nrows=3, ncols=2, height_ratios=[1, 1, 2])

# Управление цветом
ax1 = fig.add_subplot(gs[0, 1])
strm = ax1.streamplot(X, Y, U, V, color=U, linewidth=2, cmap='autumn')
fig.colorbar(strm.lines)
ax1.set_title('Цветовая схема')
# Out:
# Text(0.5, 1.0, 'Цветовая схема')

# %%
# Векторные поля - 3D

fig = plt.figure()
ax = fig.gca(projection='3d')

# Трехмерная решетка
x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

# Направления векторов
u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1, normalize=True)

plt.show()

# %%
# График с текстурой
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator
# import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Создание данных
X = np.arange(-5, 5, 0.25)
xlen = len(X)
Y = np.arange(-5, 5, 0.25)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Создаем пустой массив размером с нушу сетку и прописываем цвета в шахматном порядке
colortuple = ('y', 'b')
colors = np.empty(X.shape, dtype=str)
for y in range(ylen):
    for x in range(xlen):
        colors[x, y] = colortuple[(x + y) % len(colortuple)]

# Построение поверхности с использование масива текстуры
surf = ax.plot_surface(X, Y, Z, facecolors=colors, linewidth=0)

# Настройка оси z
ax.set_zlim(-1, 1)
ax.w_zaxis.set_major_locator(LinearLocator(6))

ax.azim = 5
ax.dist = 15
ax.elev = 30

plt.show()
